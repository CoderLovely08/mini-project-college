# %%
import pandas as pd

# %%
df = pd.read_excel('pokemon_data_250.xlsx')
df
# Out:
#                           Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0                    Bulbasaur  Grass  Poison   45      49       49       65
# 1                   Charmander   Fire     NaN   39      52       43       60
# 2    CharizardMega Charizard Y   Fire  Flying   78     104       78      159
# 3      BlastoiseMega Blastoise  Water     NaN   79     103      120      135
# 4                       Weedle    Bug  Poison   40      35       30       20
# ..                         ...    ...     ...  ...     ...      ...      ...
# 195      PumpkabooAverage Size  Ghost   Grass   49      66       70       44
# 196      GourgeistAverage Size  Ghost   Grass   65      90      122       58
# 197                   Bergmite    Ice     NaN   55      69       85       32
# 198                    Xerneas  Fairy     NaN  126     131       95      131
# 199        DiancieMega Diancie   Rock   Fairy   50     160      110      160
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head(50)
# Out:
#                          Name    Type 1    Type 2   HP  Attack  Defense  \
# 0                   Bulbasaur     Grass    Poison   45      49       49
# 1                  Charmander      Fire       NaN   39      52       43
# 2   CharizardMega Charizard Y      Fire    Flying   78     104       78
# 3     BlastoiseMega Blastoise     Water       NaN   79     103      120
# 4                      Weedle       Bug    Poison   40      35       30
# 5                      Pidgey    Normal    Flying   40      45       40
# 6                     Rattata    Normal       NaN   30      56       35
# 7                       Ekans    Poison       NaN   35      60       44
# 8                   Sandshrew    Ground       NaN   50      75       85
# 9                   Nidoqueen    Poison    Ground   90      92       87
# 10                   Clefairy     Fairy       NaN   70      45       48
# 11                 Jigglypuff    Normal     Fairy  115      45       20
# ...

# %%
newDf = df.head(50)

# %%
newDf.to_excel('test.xlsx')
